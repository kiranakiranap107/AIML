# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
train_data=pd.read_csv('C:/Users/Pramoda A S/Downloads/train.csv')
test_data=pd.read_csv('C:/Users/Pramoda A S/Downloads/test.csv')

# %%
train_data.shape
# Out:
# (891, 12)

# %%
train_data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sb.countplot('Survived',data=train_data)
plt.show()

# %%
train_data.groupby(['Sex', 'Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
train_data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar()
sb.countplot('Sex',hue='Survived',data=train_data,)
plt.show()

# %%
train_data.groupby(['Pclass', 'Survived'])['Survived'].count()
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %%
sb.countplot('Pclass', hue='Survived', data=train_data)
plt.title('Pclass: Sruvived vs Dead')
plt.show()

# %%
pd.crosstab([train_data.Sex,train_data.Survived],train_data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_791458fa_6397_11f0_a8c7_8cfbebcb5906row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_791458fa_6397_11f0_a8c7_8cfbebcb5906row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_791458fa_6397_11f0_a8c7_8cfbebcb5906row0_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_791458fa_6397_11f0_a8c7_8cfbebcb5906row0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_791458fa_6397_11f0_a8c7_8cfbebcb5906row1_col0 {
#             background-color:  #96cb66;
#             color:  #000000;
#         }    #T_791458fa_6397_11f0_a8c7_8cfbebcb5906row1_col1 {
#             background-color:  #a3d166;
#             color:  #000000;
#         }    #T_791458fa_6397_11f0_a8c7_8cfbebcb5906row1_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_791458fa_6397_11f0_a8c7_8cfbebcb5906row1_col3 {
#             background-color:  #cfe766;
#             color:  #000000;
#         }    #T_791458fa_6397_11f0_a8c7_8cfbebcb5906row2_col0 {
#             background-color:  #a7d366;
#             color:  #000000;
#         }    #T_791458fa_6397_11f0_a8c7_8cfbebcb5906row2_col1 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_791458fa_6397_11f0_a8c7_8cfbebcb5906row2_col2 {
#             background-color:  #6eb666;
#             color:  #000000;
#         }    #T_791458fa_6397_11f0_a8c7_8cfbebcb5906row2_col3 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_791458fa_6397_11f0_a8c7_8cfbebcb5906row3_col0 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_791458fa_6397_11f0_a8c7_8cfbebcb5906row3_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_791458fa_6397_11f0_a8c7_8cfbebcb5906row3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_791458fa_6397_11f0_a8c7_8cfbebcb5906row3_col3 {
#             background-color:  #f7fb66;
#             color:  #000000;
#         }    #T_791458fa_6397_11f0_a8c7_8cfbebcb5906row4_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_791458fa_6397_11f0_a8c7_8cfbebcb5906row4_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_791458fa_6397_11f0_a8c7_8cfbebcb5906row4_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_791458fa_6397_11f0_a8c7_8cfbebcb5906row4_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906level0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#                         <th id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906row0_col1" class="data row0 col1" >6</td>
#                         <td id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906row0_col2" class="data row0 col2" >72</td>
#                         <td id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906row0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906row1_col0" class="data row1 col0" >91</td>
#                         <td id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906row1_col1" class="data row1 col1" >70</td>
#                         <td id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906row1_col2" class="data row1 col2" >72</td>
#                         <td id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906row1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906level0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#                         <th id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906level1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906row2_col0" class="data row2 col0" >77</td>
#                         <td id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906row2_col1" class="data row2 col1" >91</td>
#                         <td id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906row2_col2" class="data row2 col2" >300</td>
#                         <td id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906row2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906level1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906row3_col0" class="data row3 col0" >45</td>
#                         <td id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906row3_col1" class="data row3 col1" >17</td>
#                         <td id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906row3_col2" class="data row3 col2" >47</td>
#                         <td id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906row3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906level0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906level1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906row4_col0" class="data row4 col0" >216</td>
#                         <td id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906row4_col1" class="data row4 col1" >184</td>
#                         <td id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906row4_col2" class="data row4 col2" >491</td>
#                         <td id="T_791458fa_6397_11f0_a8c7_8cfbebcb5906row4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
sb.factorplot('Pclass', 'Survived', hue='Sex', data=train_data)
plt.show()

# %%
print('Oldest person Survived was of:',train_data['Age'].max())
print('Youngest person Survived was of:',train_data['Age'].min())
print('Average person Survived was of:',train_data['Age'].mean())
# Out:
# Oldest person Survived was of: 80.0
# Youngest person Survived was of: 0.42
# Average person Survived was of: 29.69911764705882

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sb.violinplot('Pclass','Age',hue='Survived',data=train_data,split=True,ax=ax[0])
ax[0].set_title('PClass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sb.violinplot("Sex","Age", hue="Survived", data=train_data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %%
train_data.Age.isnull().any()
# Out:
# True

# %%
f,ax=plt.subplots(1,2,figsize=(20,20))
train_data[train_data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived = 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
train_data[train_data['Survived']==1].Age.plot.hist(ax=ax[1],bins=20,edgecolor='black',color='green')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
ax[1].set_title('Survived = 1')
plt.show()

# %%
pd.crosstab([train_data.SibSp],train_data.Survived).style.background_gradient('summer_r')
# Out:
# <style  type="text/css" >
#     #T_c84b6fef_6399_11f0_9964_8cfbebcb5906row0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c84b6fef_6399_11f0_9964_8cfbebcb5906row0_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_c84b6fef_6399_11f0_9964_8cfbebcb5906row1_col0 {
#             background-color:  #c4e266;
#             color:  #000000;
#         }    #T_c84b6fef_6399_11f0_9964_8cfbebcb5906row1_col1 {
#             background-color:  #77bb66;
#             color:  #000000;
#         }    #T_c84b6fef_6399_11f0_9964_8cfbebcb5906row2_col0 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_c84b6fef_6399_11f0_9964_8cfbebcb5906row2_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_c84b6fef_6399_11f0_9964_8cfbebcb5906row3_col0 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_c84b6fef_6399_11f0_9964_8cfbebcb5906row3_col1 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_c84b6fef_6399_11f0_9964_8cfbebcb5906row4_col0 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_c84b6fef_6399_11f0_9964_8cfbebcb5906row4_col1 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_c84b6fef_6399_11f0_9964_8cfbebcb5906row5_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c84b6fef_6399_11f0_9964_8cfbebcb5906row5_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_c84b6fef_6399_11f0_9964_8cfbebcb5906row6_col0 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_c84b6fef_6399_11f0_9964_8cfbebcb5906row6_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906row0_col0" class="data row0 col0" >398</td>
#                         <td id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906row0_col1" class="data row0 col1" >210</td>
#             </tr>
#             <tr>
#                         <th id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906row1_col1" class="data row1 col1" >112</td>
#             </tr>
#             <tr>
#                         <th id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906row2_col0" class="data row2 col0" >15</td>
#                         <td id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906row2_col1" class="data row2 col1" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906row3_col0" class="data row3 col0" >12</td>
#                         <td id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906row3_col1" class="data row3 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906row4_col0" class="data row4 col0" >15</td>
#                         <td id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906row4_col1" class="data row4 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906row5_col1" class="data row5 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906level0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906row6_col0" class="data row6 col0" >7</td>
#                         <td id="T_c84b6fef_6399_11f0_9964_8cfbebcb5906row6_col1" class="data row6 col1" >0</td>
#             </tr>
#     </tbody></table>

# %%
pd.crosstab(train_data.SibSp,train_data.Pclass).style.background_gradient('summer_r')
# Out:
# <style  type="text/css" >
#     #T_23055a6c_639a_11f0_8a55_8cfbebcb5906row0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_23055a6c_639a_11f0_8a55_8cfbebcb5906row0_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_23055a6c_639a_11f0_8a55_8cfbebcb5906row0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_23055a6c_639a_11f0_8a55_8cfbebcb5906row1_col0 {
#             background-color:  #7bbd66;
#             color:  #000000;
#         }    #T_23055a6c_639a_11f0_8a55_8cfbebcb5906row1_col1 {
#             background-color:  #8ac466;
#             color:  #000000;
#         }    #T_23055a6c_639a_11f0_8a55_8cfbebcb5906row1_col2 {
#             background-color:  #c6e266;
#             color:  #000000;
#         }    #T_23055a6c_639a_11f0_8a55_8cfbebcb5906row2_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_23055a6c_639a_11f0_8a55_8cfbebcb5906row2_col1 {
#             background-color:  #eef666;
#             color:  #000000;
#         }    #T_23055a6c_639a_11f0_8a55_8cfbebcb5906row2_col2 {
#             background-color:  #f8fc66;
#             color:  #000000;
#         }    #T_23055a6c_639a_11f0_8a55_8cfbebcb5906row3_col0 {
#             background-color:  #fafc66;
#             color:  #000000;
#         }    #T_23055a6c_639a_11f0_8a55_8cfbebcb5906row3_col1 {
#             background-color:  #fdfe66;
#             color:  #000000;
#         }    #T_23055a6c_639a_11f0_8a55_8cfbebcb5906row3_col2 {
#             background-color:  #fafc66;
#             color:  #000000;
#         }    #T_23055a6c_639a_11f0_8a55_8cfbebcb5906row4_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_23055a6c_639a_11f0_8a55_8cfbebcb5906row4_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_23055a6c_639a_11f0_8a55_8cfbebcb5906row4_col2 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_23055a6c_639a_11f0_8a55_8cfbebcb5906row5_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_23055a6c_639a_11f0_8a55_8cfbebcb5906row5_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_23055a6c_639a_11f0_8a55_8cfbebcb5906row5_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_23055a6c_639a_11f0_8a55_8cfbebcb5906row6_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_23055a6c_639a_11f0_8a55_8cfbebcb5906row6_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_23055a6c_639a_11f0_8a55_8cfbebcb5906row6_col2 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }</style><table id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906" ><thead>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906row0_col0" class="data row0 col0" >137</td>
#                         <td id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906row0_col1" class="data row0 col1" >120</td>
#                         <td id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906row0_col2" class="data row0 col2" >351</td>
#             </tr>
#             <tr>
#                         <th id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906row1_col0" class="data row1 col0" >71</td>
#                         <td id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906row1_col1" class="data row1 col1" >55</td>
#                         <td id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906row1_col2" class="data row1 col2" >83</td>
#             </tr>
#             <tr>
#                         <th id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906row2_col0" class="data row2 col0" >5</td>
#                         <td id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906row2_col1" class="data row2 col1" >8</td>
#                         <td id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906row2_col2" class="data row2 col2" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906row3_col1" class="data row3 col1" >1</td>
#                         <td id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906row3_col2" class="data row3 col2" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906row4_col0" class="data row4 col0" >0</td>
#                         <td id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906row4_col1" class="data row4 col1" >0</td>
#                         <td id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906row4_col2" class="data row4 col2" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906row5_col0" class="data row5 col0" >0</td>
#                         <td id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906row5_col1" class="data row5 col1" >0</td>
#                         <td id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906row5_col2" class="data row5 col2" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906level0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906row6_col0" class="data row6 col0" >0</td>
#                         <td id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906row6_col1" class="data row6 col1" >0</td>
#                         <td id="T_23055a6c_639a_11f0_8a55_8cfbebcb5906row6_col2" class="data row6 col2" >7</td>
#             </tr>
#     </tbody></table>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import re

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
data = pd.read_csv('C:/Users/Pramoda A S/Downloads/train.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
new_columns=['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
       'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
new_data=data[new_columns]
new_data.corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# Pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# Age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# Parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# Fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
f ,ax = plt.subplots(figsize = (12, 10))
colormap = plt.cm.YlOrRd_r
plt.title('Pearson Correlation of Features', size=20, weight="bold")
res = sns.heatmap(new_data.corr(), linewidths=0.1, vmax=1.0,cmap=colormap,square=True, annot= True, annot_kws={"size": 16}, ax=ax)
res.set_yticklabels(res.get_ymajorticklabels(), fontsize = 18, rotation=5, weight="bold")
res.set_xticklabels(res.get_xmajorticklabels(), fontsize = 18, weight="bold")
plt.show()

# %%
sns.pairplot(data=new_data, hue="Survived",height=2);

# %%
sns.pairplot(data=new_data, hue="Survived", kind="hist",height=2);

# %%
data[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).count().sort_values(by='Pclass', ascending=True)
# Out:
#    Pclass  Survived
# 0       1       216
# 1       2       184
# 2       3       491

# %%
plt.figure(figsize=(10,6))
font= {'family':'serif','color':'darkred','size':35}
pl = sns.color_palette("gist_rainbow", 9) 
# making error in palette style name gives a list of styles 
ax= sns.countplot(x=data['Pclass'], data=data, palette=pl)

plt.xlabel("Pclass", fontdict = font)
plt.ylabel("Count", fontdict = font)
plt.show();

# %%
data['Survived'].groupby(data['Pclass']).value_counts()
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %%
plt.figure(figsize=(10,6))
font= {'family':'serif','color':'darkred','size':35}
pl = sns.color_palette("gist_rainbow", 9)
ax = sns.countplot(data =data, x = "Sex", hue ="Pclass",palette=pl)

plt.xlabel("Pclass", fontdict = font)
plt.ylabel("Count", fontdict = font)
plt.show();
